# %%
great_wall = "The Great Wall of China was built to protect from northern invaders.\n There were many battles between the two of them, which led to multiple weapons being on and around it.\n It expanded through the reign of many rulers.\n It is now a world wonder and around 10 million people visit it every year."
taj_mahal = "The Taj Mahal was built by Shah Jahan for his wife Mumtaz Mahal when she died.\n It houses as a tomb for both of them. It took 20 years to build the entire thing.\n It is beautiful and had many jewels on and around it. Sadly, all of them were stolen.\n It is now a world wonder and more than 6 million people visit it every year."
liberty_statue = "The Statue of Liberty was a gift from the French people to the USA.\n It was made in France and shipped to the US in 350 pieces.\n It was made copper, but then exposure to air and pollution made it blue.\n There are stairs all the way to the crown, but not many people are allowed to go there.\n It is now known as Lady Liberty, and is a symbol of pride for the American people."
colosseum = "The Colosseum was built during the Flavian dynasty. It was an auditorium to hold gladiator fights.\n It was fully built, but after a while, materials were taken from it to create new buildings.\n An earthquake in the 7th century destoryed it even more.\n It is now a tourist attraction for anyone who wants to learn about Rome's history."
eiffel_tower = "The Eiffel Tower was built for the 1889 World Fair. It focused on advancements in steel and other metals.\n It was chosen between 107 other projects to be displayed during the World Fair.\n It was made by Gustave Eiffel, hence the name, and his company.\n It was built in record time, and is now part of France's culture and identity."
monument = input("Hello! What would you like to learn about?")
if monument == 'Great Wall of China':
  print(great_wall)
elif monument == 'Taj Mahal':
  print(taj_mahal)
elif monument == 'Statue of Liberty':
  print(libery_statue)
elif monument == 'Colosseum':
  print(colosseum)
elif monument == 'Eiffel Tower':
  print(eiffel_tower)
else:
  print("Sorry, we don't have this monument")
answer = input('Would you like to learn about anything else?')
if answer == 'yes':
  ask = input("which one?")
  if ask == 'Great Wall of China':
    print(great_wall)
  elif ask == 'Taj Mahal':
    print(taj_mahal)
  elif ask == 'Statue of Liberty':
    print(libery_statue)
  elif ask == 'Colosseum':
    print(colosseum)
  elif ask == 'Eiffel Tower':
    print(eiffel_tower)
  else:
    print("Sorry, we don't have this monument")
ask = input("What is your favorite monument?")
print("Thank you for coming to my Genius Hour!")
# Out:
# Hello! What would you like to learn about?Taj Mahal
# The Taj Mahal was built by Shah Jahan for his wife Mumtaz Mahal when she died.
#  It houses as a tomb for both of them. It took 20 years to build the entire thing.
#  It is beautiful and had many jewels on and around it. Sadly, all of them were stolen.
#  It is now a world wonder and more than 6 million people visit it every year.
# Would you like to learn about anything else?no
# What is your favorite monument?eiffel tower
# Thank you for coming to my Genius Hour!
