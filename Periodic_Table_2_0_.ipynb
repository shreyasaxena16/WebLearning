# %%
periodic_dict= dict({'hydrogen': 'Symbol: H. Atomic weight: 1',
                     'helium': 'Symbol: He. Atomic weight: 2',
                     'lithium': 'Symbol: Li. Atomic weight: 3',
                     'beryllium': 'Symbol: Be. Atomic weight: 4',
                     'boron': 'Symbol: B. Atomic weight: 5',
                     'carbon': 'Symbol: C. Atomic weight: 6',
                     'nitrogen': 'Symbol: N. Atomic weight: 7',
                     'oxygen': 'Symbol: O. Atomic weight: 8',
                     'fluorine': 'Symbol: F. Atomic weight: 9',
                     'neon': 'Symbol: Ne. Atomic weight: 10',
                     'sodium': 'Symbol: Na. Atomic weight: 11',
                     'magnesium': 'Symbol: Mg. Atomic weight: 12',
                     'aluminum': 'Symbol: Al. Atomic weight: 13',
                     'silicon': 'Symbol: Si. Atomic weight: 14',
                     'phosphorus': 'Symbol: P. Atomic weight: 15',
                     'sulfur': 'Symbol: S. Atomic weight: 16',
                     'cholrine': 'Symbol: Cl. Atomic weight: 17',
                     'argon': 'Symbol: Ar. Atomic weight: 18',
                     'potasium': 'Symbol: K. Atomic weight: 19',
                     'calcium': 'Symbol: Ca. Atomic weight: 20',
                     'scandium': 'Symbol: Sc. Atomic weight: 21',
                     'titanium': 'Symbol: Ti. Atomic weight: 22',
                     'vandium': 'Symbol: V. Atomic weight: 23',
                     'chromium': 'Symbol: Cr. Atomic weight: 24',
                     'manganese': 'Symbol: Mn. Atomic weight: 25',
                     'iron': 'Symbol: Fe. Atomic weight: 26',
                     'cobalt': 'Symbol: Co. Atomic weight: 27',
                     'nickel': 'Symbol: Ni. Atomic weight: 28',
                     'copper': 'Symbol: Cu. Atomic weight: 29',
                     'zinc': 'Symbol: Zn. Atomic weight: 30',
                     'peehu': 'Symbol: BANANA. Atomic weight: 75 lbs'})
element= input('Put the name of your element.').lower();
if element in periodic_dict:
  print("I have your element in my dictionary.")
  print(periodic_dict.get(element));
else:
  print("I don't have your element in my dictionary.")
