# %%
fddprint("Here is a summer mad libs. Have fun!")
place= input('A place')
past_tense_verb= input('A past tense verb')
vehicle= input('A vehicle')
number= input('A number')
plural_noun= input('A plural noun')
plural_animal= input('A plural animal')
verb_ending_in_ing= input('A verb ending in ing')
noun= input('A noun')
vehicle_two= input('A vehicle')
adjective= input('An adjective')
place_two= input('A place')
plural_animal_two= input('A plural animal')
plural_animal_three= input('A plural animal')
verb_ending_in_ing_two= input('A verb ending in ing')
place_three= input('A place')
adjective_two= input('An adjective')
plural_noun_two= input('A plural noun')
adjective_three= input('An adjective')
food= input('A food')
adjective_four= input('An adjective')
plural_noun_three= input('A plural noun')
plural_noun_four= input('A plural noun')
mad_libs= f"""
                           Summer Trip
Last summer, my family and I went to a {place} on vacation. We
{past_tense_verb} in a {vehicle} and it took {number} days to get there.
I took lots of photots of the {plural_noun} and saw a wild {plural_animal}
{verb_ending_in_ing} in the {noun}. We took a {vehicle_two} through a
{adjective} {place_two} and there were {plural_animal_two} and
{plural_animal_three} {verb_ending_in_ing_two} all around us! At night we went
to a {place_three} and heard {adjective_two} {plural_noun_two} while we ate
{adjective_three} {food}. I can't wait to share my {adjective_four} photos of
{plural_noun_three} and {plural_noun_four} with my friends!"""
print(mad_libs)
# Out:
# Here is a summer mad libs. Have fun!
# A placeRegina
# A past tense verbWent
# A vehicleCar
# A number2
# A plural nounakjlsdlkl
# A plural animalhjkehfw
# A verb ending in ingjsjkf
# A nounjdfhj
# A vehiclehfdjfsd
# An adjective
# A placeffdg
# A plural animal
# A plural animalgfearge
# A verb ending in inggfs
# A placefdgf
# An adjectivejjd
# A plural nountte
# An adjectivenb
# A foodaegtrs\
# An adjectivetjutij
