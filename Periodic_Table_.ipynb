# %%
element = input('Put in the name of the element.')
if element == 'Hydrogen':
  hydrogen = True
  print("Hydrogen's symbol is H. Its atomic weight is 1.")
elif element == 'Helium':
  helium = True
  print("Helium's symbol is He. Its atomic weight is 2.")
elif element == 'Lithium':
  lithium = True
  print("Lithium's symbol is Li. Its atomic weight is 3.")
elif element == 'Beryllium':
  beryllium = True
  print("Beryllium's symbol is Be. its atomic weight is 4.")
elif element == 'Boron':
  boron = True
  print("Boron's symbol is B. Its atomic weight is 5.")
elif element == 'Carbon':
  carbon = True
  print("Carbon's symbol is C. Its atomic weight is 6.")
elif element == 'Nitrogen':
  nitrogen = True
  print("Nitrogen's symbol is N. Its atomic weight is 7.")
elif element == 'Oxygen':
  oxygen = True
  print("Oxygen's symbol is O. Its atomic weight is 8.")
elif element == 'Fluorine':
  fluorine = True
  print("Fluorine's symbol is F. Its atomic weight is 9.")
elif element == 'Neon':
  neon = True
  print("Neon's symbol is Ne. Its atomic weight is 10.")
elif element == 'Sodium':
  sodium = True
  print("Sodium's symbol is Na. Its atomic weight is 11.")
elif element == 'Magnesium':
  magnesium = True
  print("Magnesium's symbol is Mg. Its atomic weight is 12.")
elif element == 'Aluminum':
  aluminum = True
  print("Aluminum's symbol is Al. Its atomic weight is 13.")
elif element == 'Silicon':
  silicon = True
  print("Silicon's symbol is Si. Its atomic weight is 14.")
elif element == 'Phosphorus':
  phosphorus = True
  print("Phosphorus's symbol is P. Its atomic weight is 15.")
elif element == 'Sulfur':
  sulfur = True
  print("Sulfur's symbol is S. Its atomic weight is 16.")
elif element == 'Chlorine':
  chlorine = True
  print("Chlorine's symbol is Cl. Its atomic weight is 17.")
elif element == 'Argon':
  argon = True
  print("Argon's symbol is Ar. Its atomic weight is 18.")
elif element == 'Potasium':
  potasium = True
  print("Potasium's symbol is K. Its atomic weight is 19.")
elif element == 'Calsium':
  calsium = True
  print("Calcium's symbol is Ca. Its atomic weight is 20.")
