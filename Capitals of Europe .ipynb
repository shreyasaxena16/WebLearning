# %%
europe_dict= dict(
    {
                    'uk':'London',
                   'france':'Paris',
                   'spain':'Madrid',
                   'italy':'Rome',
                   'greece':'Athens',
                   'russia':'Moscow',
                   'norway':'Oslo',
                   'sweden':'Stockholm',
                   'finland':'Helsinki',
                   'denmark':'Copenhagen',
                   'iceland':'Reykjavík',
                   'ireland':'Dublin',
                   'germany':'Berlin',
                   'poland':'Warsaw',
                   'ukraine':'Kyiv',
                   'turkey':'Ankara',
                   'portugal':'Lisbon',
                   'belgium':'Brussels',
                   'belarus':'Minsk',
                   'bulgaria':'Sofia',
                   'switzerland':'Bern',
                   'estonia':'Tallinn',
                   'latvia':'Riga',
                   'lithuania':'Vilnius',
                   'austria':'Vienna',
                   'czech republic':'Prague',
                   'hungary':'Budapest',
                   'romania':'Bucharest',
                   'bosnia and herzegovina':'Sarajevo',
                   'croatia':'Zagreb',
                   'north macedonia':'Skopje',
                   'netherlands':'Amsterdam',
                   'moldova':'Chișinău',
                   'montenegro':'Podgorica',
                   'albania':'Tirana',
                   'kosovo':'Pristina',
                   'serbia':'Belgrade',
                   'slovakia':'Bratislava',
                   'slovenia':'Ljubljana',
                   'cyprus':'Nicosia',
                   'liechtenstein':'Vaduz',
                   'malta':'Valletta',
                   'monaco':'Monaco City',
                   'andorra':'Andorra la Vella',
                   'vatican city':'Vatican City',
                   'san marino':'San Marino',
                   'luxembourg':'Luxembourg City'
                   }
                  )
country= input('Write a country in Europe').lower();
if country in europe_dict:
  print("This country is in Europe.")
  print(europe_dict.get(country));
else:
  print("This country is not in Europe")
# Out:
# Write a country in Europemonaco
# This country is in Europe.
# Monaco City
